# %%
import numpy as np
import sys
sys.path.append("/global/cfs/projectdirs/act/data/mlokken/oriented_stacks/oriented_superclustering/")
from catalog import Catalog
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
catalogfile = "/pscratch/sd/m/mlokken/actxdesi/flam_logmstar11p2_analysis/flam_11p2_0pt90_0pt95_10pt0Mpc_asym_xy.csv"
cat = Catalog(pathInCatalog=catalogfile)
catnucut = Catalog(pathInCatalog=catalogfile, config={'nu_min':2, 'e_min':0.3, 'e_max':20})
# Out:
# - read input catalog from /pscratch/sd/m/mlokken/actxdesi/flam_logmstar11p2_analysis/flam_11p2_0pt90_0pt95_10pt0Mpc_asym_xy.csv
# - read input catalog from /pscratch/sd/m/mlokken/actxdesi/flam_logmstar11p2_analysis/flam_11p2_0pt90_0pt95_10pt0Mpc_asym_xy.csv
# [False  True  True ... False  True  True]
# [ True  True  True ...  True  True  True] [False  True  True ... False  True  True]
# [False  True  True ... False  True  True] [ True False False ... False False False]
# [False False False ... False False False] [False  True  True ...  True  True  True]

# %%
plt.hist(cat.nu)
plt.hist(catnucut.nu)
# Out:
# (array([7.2830e+04, 3.2323e+04, 1.2630e+04, 4.6990e+03, 1.7380e+03,
#         6.7200e+02, 2.2600e+02, 1.2700e+02, 6.9000e+01, 1.7000e+01]),
#  array([ 2.00001986,  4.00297668,  6.0059335 ,  8.00889032, 10.01184714,
#         12.01480396, 14.01776078, 16.0207176 , 18.02367443, 20.02663125,
#         22.02958807]),
#  <BarContainer object of 10 artists>)

# %%
bins = np.linspace(0,3, 40)
plt.hist(cat.e, bins=bins)
plt.hist(catnucut.e, bins=bins)
# Out:
# (array([    0.,     0.,     0.,  2089., 17252., 13328.,  9941.,  8109.,
#          6647.,  5464.,  4485.,  3890.,  3493.,  3004.,  2694.,  2424.,
#          2150.,  1946.,  1813.,  1652.,  1533.,  1362.,  1262.,  1150.,
#          1130.,  1014.,   983.,   913.,   804.,   795.,   717.,   627.,
#           718.,   582.,   566.,   611.,   549.,   502.,   510.]),
#  array([0.        , 0.07692308, 0.15384615, 0.23076923, 0.30769231,
#         0.38461538, 0.46153846, 0.53846154, 0.61538462, 0.69230769,
#         0.76923077, 0.84615385, 0.92307692, 1.        , 1.07692308,
#         1.15384615, 1.23076923, 1.30769231, 1.38461538, 1.46153846,
#         1.53846154, 1.61538462, 1.69230769, 1.76923077, 1.84615385,
#         1.92307692, 2.        , 2.07692308, 2.15384615, 2.23076923,
#         2.30769231, 2.38461538, 2.46153846, 2.53846154, 2.61538462,
#         2.69230769, 2.76923077, 2.84615385, 2.92307692, 3.        ]),
#  <BarContainer object of 39 artists>)

# %%
bins = np.linspace(0,50, 40)
plt.hist(cat.e, bins=bins)
plt.hist(catnucut.e, bins=bins)
plt.xscale('log')
plt.yscale('log')

# %%
plt.hist(catnucut.nu)
# Out:
# (array([487147.,      0.,      0.,      0.,      0.,      0.,      0.,
#              0.,      0., 241352.]),
#  array([1.82296144, 1.84815437, 1.87334729, 1.89854022, 1.92373315,
#         1.94892607, 1.974119  , 1.99931193, 2.02450485, 2.04969778,
#         2.07489071]),
#  <BarContainer object of 10 artists>)
