# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "/home/mlokken/oriented_stacking/oriented_superclustering/")
import catalog

# %%
# pkdata_python = catalog.Catalog(pathInCatalog="/mnt/scratch-lustre/mlokken/stacking/flamingo/dr1_lrg_allpython/lrg11p2_0pt90_0pt95_10pt0Mpc_asym_xy.csv")
pkdata_python = catalog.Catalog(pathInCatalog="/mnt/scratch-lustre/mlokken/stacking/flamingo/dr1_lrg_allpython/lrg11p2_0pt90_0pt93_10pt0Mpc_asym_xy.csv")
# Out:
# - read input catalog from /mnt/scratch-lustre/mlokken/stacking/flamingo/dr1_lrg_allpython/lrg11p2_0pt90_0pt93_10pt0Mpc_asym_xy.csv

# %%
len(pkdata_python.alpha)
# Out:
# 364728

# %%
plt.hist(pkdata_python.nu)
# Out:
# (array([2.09029e+05, 1.05691e+05, 3.43920e+04, 1.08570e+04, 3.20600e+03,
#         1.11000e+03, 3.14000e+02, 8.20000e+01, 3.40000e+01, 1.30000e+01]),
#  array([ 0.        ,  2.29992938,  4.59985877,  6.89978815,  9.19971753,
#         11.49964692, 13.7995763 , 16.09950568, 18.39943506, 20.69936445,
#         22.99929383]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(pkdata_python.e, bins = np.linspace(0, 1, 20))
# Out:
# (array([43413., 54263., 53332., 45812., 32634., 23779., 18022., 14419.,
#         11006.,  8571.,  6860.,  5504.,  4560.,  3771.,  3316.,  2683.,
#          2241.,  2013.,  1712.]),
#  array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#         0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#         0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#         0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ]),
#  <BarContainer object of 19 artists>)

# %%
pkdata_fortran = catalog.Catalog(pathInCatalog="/mnt/raid-cita/mlokken/data/flamingo/stacking_points/lrg11p2_lrg11p2_nu10gt2_e10gtpt3_o10_100pct_0.9_0.95.csv")
# Out:
# - read input catalog from /mnt/raid-cita/mlokken/data/flamingo/stacking_points/lrg11p2_lrg11p2_nu10gt2_e10gtpt3_o10_100pct_0.9_0.95.csv

# %%
len(pkdata_fortran.alpha)
# Out:
# 241926

# %%
# make pandas df
import pandas as pd
df_python = pd.DataFrame({
    "RA": pkdata_python.RA,
    "DEC": pkdata_python.DEC,
    "alpha": pkdata_python.alpha,
    "Z": pkdata_python.Z,
    "x_asym": pkdata_python.x_asym,
    "y_asym": pkdata_python.y_asym,
    "e": pkdata_python.e,
    "nu": pkdata_python.nu
})

# %%
df_fortran = pd.DataFrame({
    "RA": pkdata_fortran.RA,
    "DEC": pkdata_fortran.DEC,
    "alpha": pkdata_fortran.alpha,
    "Z": pkdata_fortran.Z,
    "x_asym": pkdata_fortran.x_asym,
    "y_asym": pkdata_fortran.y_asym,
})

# %%
# histogram the original angles
# plt.hist(df_python.alpha, bins=50, alpha=0.5, label='Python')
# plt.hist(df_fortran.alpha, bins=50, alpha=0.5, label='Fortran')
plt.axvline(np.pi/4, color='g', linestyle='--', label='pi/4')
plt.axvline(np.pi/2, color='k', linestyle='--', label='pi/2')
plt.xlabel('Alpha (radians)')
plt.ylabel('Count')
plt.axvline(np.pi, color='r', linestyle='--', label='pi')
plt.axvline(3*np.pi/4, color='b', linestyle='--', label='3pi/4')

# plt.axvline(-np.pi, color='r', linestyle='--', label='-pi')
# plt.axvline(-np.pi/2, color='k', linestyle='--', label='-pi/2 degrees')
# plt.axvline(3*np.pi/2, color='k', linestyle='--', label='3pi/2')
plt.hist(df_python.alpha%np.pi, bins=50, alpha=0.5, label='1024')
plt.hist(df_fortran.alpha%np.pi, bins=50, alpha=0.5, label='512')

plt.legend()

# %%
# histogram the original angles
# plt.hist(df_python.alpha, bins=50, alpha=0.5, label='Python')
# plt.hist(df_fortran.alpha, bins=50, alpha=0.5, label='Fortran')
plt.axvline(np.pi/4, color='g', linestyle='--', label='pi/4')
plt.axvline(np.pi/2, color='k', linestyle='--', label='pi/2')
plt.xlabel('Alpha (radians)')
plt.ylabel('Count')
plt.axvline(np.pi, color='r', linestyle='--', label='pi')
plt.axvline(3*np.pi/4, color='b', linestyle='--', label='3pi/4')

# plt.axvline(-np.pi, color='r', linestyle='--', label='-pi')
# plt.axvline(-np.pi/2, color='k', linestyle='--', label='-pi/2 degrees')
# plt.axvline(3*np.pi/2, color='k', linestyle='--', label='3pi/2')
plt.hist(df_python.alpha%np.pi, bins=50, alpha=0.5, label='Python', density=True)
plt.hist(df_python.alpha[df_python.nu>5]%np.pi, bins=50, alpha=0.5, label='Python nu>3', density=True)
# plt.hist(df_python.alpha[df_python.e>.8]%np.pi, bins=50, alpha=0.5, label='Python e>.5', density=True)

plt.legend(loc='lower left')

# %%
# examine a map
import healpy as hp
odmap = hp.read_map("/mnt/scratch-lustre/mlokken/stacking/flamingo/dr1_lrg_allpython/maps/odmap_asym_xy_100_3152pt8_3192pt8.fits")
smthmap = hp.smoothing(odmap, fwhm=np.deg2rad(10/60.)) # 10 arcmin smoothing

# %%
hp.mollview(smthmap)

# %%
hp.cartview(smthmap, lonra=[0,60], latra=[-30,15])

# %%
# get the z range for that map
chimin = 3152.8
chimax = 3192.8
from astropy.cosmology import z_at_value, Planck18 as cosmo
import astropy.units as u
zlow = z_at_value(cosmo.comoving_distance, chimin*u.Mpc)
zhigh = z_at_value(cosmo.comoving_distance, chimax*u.Mpc)

# %%
zlow, zhigh
# Out:
# (<Quantity 0.90500411 redshift>, <Quantity 0.92028828 redshift>)

# %%
# plot arrows for angles on the map
lonmax = 10
lonmin = 0
latmax = 5
latmin = -5
cutout = hp.cartview(smthmap, lonra=[lonmin, lonmax], latra=[latmin, latmax], return_projected_map=True)
from astropy.wcs import WCS
wcs = WCS(naxis=2)
wcs.wcs.crpix = [cutout.shape[1]/2, cutout.shape[0]/2]
wcs.wcs.cdelt = [-(lonmax-lonmin)/cutout.shape[1], (latmax-latmin)/cutout.shape[0]]
wcs.wcs.crval = [(lonmax+lonmin)/2, (latmax+latmin)/2]
wcs.wcs.ctype = ["RA---CAR", "DEC--CAR"]
fig, ax = plt.subplots(subplot_kw={'projection': wcs}, figsize=(10,8))
ax.imshow(cutout, origin='lower', cmap='viridis')
# plot arrows for angles on the map
in_cutout = (df_python.RA > lonmin) & (df_python.RA < lonmax) & (df_python.DEC > latmin) & (df_python.DEC < latmax) & (df_python.Z > zlow) & (df_python.Z < zhigh)
# reduce catalog
cat_reduced = df_python[in_cutout]

Xpix, Ypix = wcs.wcs_world2pix(cat_reduced.RA, cat_reduced.DEC, 0)

for i in range(sum(in_cutout)):
    
    # ax.arrow(Xpix[i], Ypix[i], cat_reduced.e.iloc[i]*np.cos(cat_reduced.alpha.iloc[i]), cat_reduced.e.iloc[i]*np.sin(cat_reduced.alpha.iloc[i]), head_width=0.1, head_length=0.1, fc='r', ec='r')
    ax.arrow(Xpix[i], Ypix[i], 20*np.cos(cat_reduced.alpha.iloc[i]), -20*np.sin(cat_reduced.alpha.iloc[i]), head_width=0.1, head_length=0.1, fc='r', ec='r')

# %%
plt.hist(cat_reduced.nu)
# Out:
# (array([409., 310., 220.,  81.,  34.,  18.,   7.,   4.,   0.,   3.]),
#  array([ 0.06650223,  1.28960738,  2.51271254,  3.73581769,  4.95892285,
#          6.182028  ,  7.40513316,  8.62823831,  9.85134347, 11.07444863,
#         12.29755378]),
#  <BarContainer object of 10 artists>)

# %%
# plot where nu and e are

lonmax = 10
lonmin = 0
latmax = 5
latmin = -5
cutout = hp.cartview(smthmap, lonra=[lonmin, lonmax], latra=[latmin, latmax], return_projected_map=True)
from astropy.wcs import WCS
wcs = WCS(naxis=2)
wcs.wcs.crpix = [cutout.shape[1]/2, cutout.shape[0]/2]
wcs.wcs.cdelt = [-(lonmax-lonmin)/cutout.shape[1], (latmax-latmin)/cutout.shape[0]]
wcs.wcs.crval = [(lonmax+lonmin)/2, (latmax+latmin)/2]
wcs.wcs.ctype = ["RA---CAR", "DEC--CAR"]
fig, ax = plt.subplots(subplot_kw={'projection': wcs}, figsize=(10,8))
ax.imshow(cutout, origin='lower', cmap='viridis')
# plot arrows for angles on the map
in_cutout = (df_python.RA > lonmin) & (df_python.RA < lonmax) & (df_python.DEC > latmin) & (df_python.DEC < latmax) & (df_python.Z > zlow) & (df_python.Z < zhigh)
# reduce catalog
cat_reduced = df_python[in_cutout]

Xpix, Ypix = wcs.wcs_world2pix(cat_reduced.RA, cat_reduced.DEC, 0)

for i in range(sum(in_cutout)):
    
    # ax.arrow(Xpix[i], Ypix[i], cat_reduced.e.iloc[i]*np.cos(cat_reduced.alpha.iloc[i]), cat_reduced.e.iloc[i]*np.sin(cat_reduced.alpha.iloc[i]), head_width=0.1, head_length=0.1, fc='r', ec='r')
    # ax.arrow(Xpix[i], Ypix[i], 20*np.cos(cat_reduced.alpha.iloc[i]), -20*np.sin(cat_reduced.alpha.iloc[i]), head_width=0.1, head_length=0.1, fc='r', ec='r')
    ax.scatter(Xpix[i], Ypix[i], s=4*cat_reduced.nu.iloc[i], cmap='afmhot', edgecolor='k')

# %%
# plot where nu and e are

lonmax = 10
lonmin = 0
latmax = 5
latmin = -5
cutout = hp.cartview(smthmap, lonra=[lonmin, lonmax], latra=[latmin, latmax], return_projected_map=True)
from astropy.wcs import WCS
wcs = WCS(naxis=2)
wcs.wcs.crpix = [cutout.shape[1]/2, cutout.shape[0]/2]
wcs.wcs.cdelt = [-(lonmax-lonmin)/cutout.shape[1], (latmax-latmin)/cutout.shape[0]]
wcs.wcs.crval = [(lonmax+lonmin)/2, (latmax+latmin)/2]
wcs.wcs.ctype = ["RA---CAR", "DEC--CAR"]
fig, ax = plt.subplots(subplot_kw={'projection': wcs}, figsize=(10,8))
ax.imshow(cutout, origin='lower', cmap='viridis')
# plot arrows for angles on the map
in_cutout = (df_python.RA > lonmin) & (df_python.RA < lonmax) & (df_python.DEC > latmin) & (df_python.DEC < latmax) & (df_python.Z > zlow) & (df_python.Z < zhigh)
# reduce catalog
cat_reduced = df_python[in_cutout]

Xpix, Ypix = wcs.wcs_world2pix(cat_reduced.RA, cat_reduced.DEC, 0)

for i in range(sum(in_cutout)):
    
    # ax.arrow(Xpix[i], Ypix[i], cat_reduced.e.iloc[i]*np.cos(cat_reduced.alpha.iloc[i]), cat_reduced.e.iloc[i]*np.sin(cat_reduced.alpha.iloc[i]), head_width=0.1, head_length=0.1, fc='r', ec='r')
    # ax.arrow(Xpix[i], Ypix[i], 20*np.cos(cat_reduced.alpha.iloc[i]), -20*np.sin(cat_reduced.alpha.iloc[i]), head_width=0.1, head_length=0.1, fc='r', ec='r')
    ax.scatter(Xpix[i], Ypix[i], s=4*cat_reduced.nu.iloc[i], cmap='afmhot', edgecolor='k')

# %%
# do the pi/4, pi/2, 3pi/4, pi peaks correspond to low-e or low-nu locations?
weird = np.isclose(df_python.alpha%np.pi, np.pi/4, atol=0.01) | np.isclose(df_python.alpha%np.pi, np.pi/2, atol=0.01) | np.isclose(df_python.alpha%np.pi, 3*np.pi/4, atol=0.01) | np.isclose(df_python.alpha%np.pi, 0, atol=0.01)

plt.scatter(df_python.nu[~weird], df_python.e[~weird], label='Other angles', alpha=0.5)
plt.scatter(df_python.nu[weird], df_python.e[weird], label='Weird angles', alpha=0.5)
plt.xlim([0, 20])
plt.ylim([0,2])
plt.ylabel("e")
plt.xlabel("nu")
plt.legend()

# %%
plt.hist(df_python.e[weird], bins=np.linspace(0, 1, 20), alpha=0.5, label='Weird', density=True)
plt.hist(df_python.e[~weird], bins=np.linspace(0, 1, 20), alpha=0.5, label='Other', density=True)
plt.legend()

# %%
selection = (df_python.nu > 4) & (df_python.e > .3)

# %%
# histogram the original angles
# plt.hist(df_python.alpha, bins=50, alpha=0.5, label='Python')
# plt.hist(df_fortran.alpha, bins=50, alpha=0.5, label='Fortran')
plt.axvline(np.pi/4, color='g', linestyle='--', label='pi/4')
plt.axvline(np.pi/2, color='k', linestyle='--', label='pi/2')
plt.xlabel('Alpha (radians)')
plt.ylabel('Count')
plt.axvline(np.pi, color='r', linestyle='--', label='pi')
plt.axvline(3*np.pi/4, color='b', linestyle='--', label='3pi/4')

# plt.axvline(-np.pi, color='r', linestyle='--', label='-pi')
# plt.axvline(-np.pi/2, color='k', linestyle='--', label='-pi/2 degrees')
# plt.axvline(3*np.pi/2, color='k', linestyle='--', label='3pi/2')
plt.hist(df_python.alpha%np.pi, bins=50, alpha=0.5, label='Without selection', density=True)
plt.hist(df_python.alpha[selection]%np.pi, bins=50, alpha=0.5, label='With', density=True)

plt.legend()

# %%
plt.hist(df_python.nu[weird], bins=np.linspace(0, 10, 50), alpha=0.5, label='Weird', density=True)
plt.hist(df_python.nu[~weird], bins=np.linspace(0, 10, 50), alpha=0.5, label='Other', density=True)
plt.legend()

# %%
# sort boht by reshift
df_python_sorted = df_python.sort_values(by="Z").reset_index(drop=True)
df_fortran_sorted = df_fortran.sort_values(by="Z").reset_index(drop=True)
print(df_python_sorted.head())
print(df_fortran_sorted.head())
# Out:
#            RA        DEC     alpha         Z  x_asym  y_asym
# 0  284.331120 -18.114580  1.639528  0.907855      -1      -1
# 1  283.651150  -1.058584  2.175551  0.907855      -1      -1
# 2   64.437930 -15.457368  1.205355  0.907855       1       1
# 3   58.329006 -14.693891 -2.405901  0.907855       1       1
# 4  243.134340   0.195812 -2.886846  0.907855      -1      -1
#            RA        DEC     alpha         Z  x_asym  y_asym
# 0  -75.673841 -18.092190  1.616600  0.907855    -1.0    -1.0
# 1  -76.333009  -1.044509  2.221372  0.907855    -1.0    -1.0
# 2   64.423826 -15.442787  4.298656  0.907855     1.0    -1.0
# 3   58.315431 -14.708788  3.887189  0.907855     1.0    -1.0
# 4 -116.894525   0.186509  0.360271  0.907855     1.0     1.0

# %%
# df_fortran RAs are -180 to 180, while df_python ones are 0 to 360. Convert df_fortran to 0 to 360 system.
df_fortran_sorted["RA"] = df_fortran_sorted["RA"] % 360

# %%
print(df_python_sorted.head())
print(df_fortran_sorted.head())
# Out:
#            RA        DEC     alpha         Z  x_asym  y_asym
# 0  284.331120 -18.114580  1.639528  0.907855      -1      -1
# 1  283.651150  -1.058584  2.175551  0.907855      -1      -1
# 2   64.437930 -15.457368  1.205355  0.907855       1       1
# 3   58.329006 -14.693891 -2.405901  0.907855       1       1
# 4  243.134340   0.195812 -2.886846  0.907855      -1      -1
#            RA        DEC     alpha         Z  x_asym  y_asym
# 0  284.326159 -18.092190  1.616600  0.907855    -1.0    -1.0
# 1  283.666991  -1.044509  2.221372  0.907855    -1.0    -1.0
# 2   64.423826 -15.442787  4.298656  0.907855     1.0    -1.0
# 3   58.315431 -14.708788  3.887189  0.907855     1.0    -1.0
# 4  243.105475   0.186509  0.360271  0.907855     1.0     1.0

# %%
# alphas are also defined differently sometimes. They are headless vectors so we only care about the rotation from 0 to 180.
df_python_sorted["alpha"] = df_python_sorted["alpha"] % np.pi
df_fortran_sorted["alpha"] = df_fortran_sorted["alpha"] % np.pi
print(df_python_sorted.head())
print(df_fortran_sorted.head())
# Out:
#            RA        DEC     alpha         Z  x_asym  y_asym
# 0  284.331120 -18.114580  1.639528  0.907855      -1      -1
# 1  283.651150  -1.058584  2.175551  0.907855      -1      -1
# 2   64.437930 -15.457368  1.205355  0.907855       1       1
# 3   58.329006 -14.693891  0.735692  0.907855       1       1
# 4  243.134340   0.195812  0.254747  0.907855      -1      -1
#            RA        DEC     alpha         Z  x_asym  y_asym
# 0  284.326159 -18.092190  1.616600  0.907855    -1.0    -1.0
# 1  283.666991  -1.044509  2.221372  0.907855    -1.0    -1.0
# 2   64.423826 -15.442787  1.157063  0.907855     1.0    -1.0
# 3   58.315431 -14.708788  0.745597  0.907855     1.0    -1.0
# 4  243.105475   0.186509  0.360271  0.907855     1.0     1.0

# %%
alpha_diffs = []
x_asym_diffs = []
y_asym_diffs = []
counter = 0
for i in range(10000):
    z_python = df_python_sorted.loc[i, "Z"]
    z_fortran = df_python_sorted.loc[i, "Z"]
    if np.isclose(z_python, z_fortran, atol=.05) and np.isclose(df_python_sorted.loc[i, "RA"], df_fortran_sorted.loc[i, "RA"], atol=.1) and np.isclose(df_python_sorted.loc[i, "DEC"], df_fortran_sorted.loc[i, "DEC"], atol=.1):
        # print(f"Match found at index {i} in Python and index {i} in Fortran: {df_python_sorted.loc[i]} and {df_fortran_sorted.loc[i]}")
        # # plot the alphas as headless vectors
        # plt.quiver(0, 0, np.cos(df_python_sorted.loc[i, "alpha"]), np.sin(df_python_sorted.loc[i, "alpha"]), angles='xy', scale_units='xy', scale=1, color='r', label='Python')
        # # add the opposite arrow
        # plt.quiver(0, 0, -np.cos(df_python_sorted.loc[i, "alpha"]), -np.sin(df_python_sorted.loc[i, "alpha"]), angles='xy', scale_units='xy', scale=1, color='r')
        # plt.quiver(0, 0, np.cos(df_fortran_sorted.loc[j, "alpha"]), np.sin(df_fortran_sorted.loc[j, "alpha"]), angles='xy', scale_units='xy', scale=1, color='b', label='Fortran')
        # plt.quiver(0, 0, -np.cos(df_fortran_sorted.loc[j, "alpha"]), -np.sin(df_fortran_sorted.loc[j, "alpha"]), angles='xy', scale_units='xy', scale=1, color='b')
        # plt.show()
        # plt.clf()
        
        # check alpha differences considering only headless vectors
        alpha_diffs.append(df_python_sorted.loc[i, "alpha"] - df_fortran_sorted.loc[i, "alpha"])
        counter += 1
        if counter%10 == 0:
            print(f"Found {counter} matches so far.")
            
        # check aysymmetry matches
        x_asym_diff = np.abs(df_python_sorted.loc[i, "x_asym"] - df_fortran_sorted.loc[i, "x_asym"])
        y_asym_diff = np.abs(df_python_sorted.loc[i, "y_asym"] - df_fortran_sorted.loc[i, "y_asym"])
        
        x_asym_diffs.append(x_asym_diff)
        y_asym_diffs.append(y_asym_diff)

# %%
plt.hist(np.degrees(alpha_diffs), bins=200)
plt.xlim([-20, 20])
plt.xlabel("Alpha difference Python - Fortran [deg]")
# Out:
# Text(0.5, 0, 'Alpha difference Python - Fortran [deg]')

# %%
plt.hist(np.abs(x_asym_diffs), bins=200)
plt.xlabel("x_asym difference Python - Fortran")
plt.hist(np.abs(y_asym_diffs), bins=200)
plt.xlabel("y_asym difference Python - Fortran")
# if equal amounts 0 and 2, there was no coherence in the asymmetry determination
# Out:
# Text(0.5, 0, 'y_asym difference Python - Fortran')

# %%
rand = np.random.choice(np.arange(len(x_asym_diffs)), replace=False, size=10000)

# %%
# observing an excess in alphas at multiples of pi/4. Plot the ra, dec and color if near pi/4 to see if it related to position on sky
# plt.scatter(df_python_sorted["RA"].iloc[rand], df_python_sorted["DEC"].iloc[rand], c=np.isclose(df_python_sorted["alpha"].iloc[rand]%np.pi, np.pi/4, atol=0.1), cmap="coolwarm", s=5)
weird = np.isclose(df_python_sorted["alpha"].iloc[rand]%np.pi, np.pi/4, atol=0.01)
plt.scatter(df_python_sorted["RA"].iloc[rand][weird], df_python_sorted["DEC"].iloc[rand][weird], s=5)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.colorbar(label="Alpha near pi/4")
