# %%
from postprocessing import retrieve_stack_info, plotstack
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
ls /pscratch/sd/m/mlokken/actxdesi/desidr2lrg_analysis/tSZ_p5_p6//
# Out:
# ACT_y_fid_consol_stacks_z0.50_0.60_lrg_cigale_masked_0pt50_0pt60_8pt0Mpc_asym_xy.h5
# combined_mask.fits
# lrg_cigale_masked_0pt50_0pt60_8pt0Mpc_asym_xy.csv
# region_labels_48reg.txt
# region_splits.png
# stacking_config_used.yaml

# %%
tsz = "/pscratch/sd/m/mlokken/actxdesi/desidr2lrg_analysis/tSZ_p5_p6/ACT_y_fid_consol_stacks_z0.50_0.60_lrg_cigale_masked_0pt50_0pt60_8pt0Mpc_asym_xy.h5"
act_tsz = retrieve_stack_info(tsz, format="constant_comoving", binsize=2, crop_center=0.0, r_m0_normalization=8)
kszimg = plotstack(act_tsz.avg_img, act_tsz.radius,cmap='grey', label=r'tSZ')
# Out:
# retrieving data from /pscratch/sd/m/mlokken/actxdesi/desidr2lrg_analysis/tSZ_p5_p6/ACT_y_fid_consol_stacks_z0.50_0.60_lrg_cigale_masked_0pt50_0pt60_8pt0Mpc_asym_xy.h5
# Stacks from the following maps available: ACT_y_fid
# Reading stack data from the map: ACT_y_fid
# Number of splits 48
# 5
# 0
# 5
# 1
# 5
# 2
# 5
# 3
# 5
# 4
# /pscratch/sd/m/mlokken/actxdesi/oriented_superclustering/src/stack_statistics.py:24: RuntimeWarning: invalid value encountered in scalar divide
#   corcoeff = covmat[i, j] / np.sqrt(covmat[i, i] * covmat[j, j])

# %%
tsz = "/pscratch/sd/m/mlokken/actxdesi/desidr2lrg_analysis/tSZ_p5_p6_masked//ACT_y_fid_consol_stacks_z0.50_0.60_lrg_cigale_masked_0pt50_0pt60_8pt0Mpc_asym_xy.h5"
act_tsz = retrieve_stack_info(tsz, format="constant_comoving", binsize=2, crop_center=0.0, r_m0_normalization=8)
kszimg = plotstack(act_tsz.avg_img, act_tsz.radius,cmap='grey', label=r'tSZ')
# Out:
# retrieving data from /pscratch/sd/m/mlokken/actxdesi/desidr2lrg_analysis/tSZ_p5_p6_masked//ACT_y_fid_consol_stacks_z0.50_0.60_lrg_cigale_masked_0pt50_0pt60_8pt0Mpc_asym_xy.h5
# Stacks from the following maps available: ACT_y_fid
# Reading stack data from the map: ACT_y_fid
# Number of splits 48
# 5
# 0
# 5
# 1
# 5
# 2
# 5
# 3
# 5
# 4
# /pscratch/sd/m/mlokken/actxdesi/oriented_superclustering/src/stack_statistics.py:24: RuntimeWarning: invalid value encountered in scalar divide
#   corcoeff = covmat[i, j] / np.sqrt(covmat[i, i] * covmat[j, j])
